# %% [markdown]
# # Intro To Python
# - [Input and Output](#Input-and-Output)
# - [Python Variables](#Python-Variables)
# - [Arithmetic and Boolean Operators](#Arithmetic-and-Boolean-Operators)
# - [Python Modules](#Python-Modules)

# %% [markdown]
# ## Input and Ouput

# %%
input()
# Out:
#  Hi there!
# 'Hi there!'

# %%
input("Please Type Your Name:")
# Out:
# Please Type Your Name: Fatha dd
# 'Fatha dd'

# %%
print("Hi There!")
# Out:
# Hi There!

# %%
print("AAAAAAAAA","BBBBB","CCCCCCCCCC")
# Out:
# AAAAAAAAA BBBBB CCCCCCCCCC

# %%
print("ABCD")
# Out:
# ABCD

# %% [markdown]
# ## Python Variables

# %%
a="This is a sentence."
b = "cat"
c = "Q"
d = 8
ABCD = "ABCD"
radius = 10
square10 = 5

# %%
print(a)
# Out:
# This is a sentence.

# %%
print(b,c,d)
# Out:
# cat Q 8

# %%
ABCD
# Out:
# 'ABCD'

# %%
type(a)
# Out:
# str

# %%
type(radius)
# Out:
# int

# %%
b="This is another sentence."

# %%
b
# Out:
# 'This is another sentence.'

# %%
print(b)
# Out:
# This is another sentence.

# %%
name=input("Type your name here:")
# Out:
# Type your name here: Fatha dd

# %%
print(name)
# Out:
# Fatha dd

# %% [markdown]
# ## Arithmetic and Boolean Operators

# %%
5+7
# Out:
# 12

# %%
5-7
# Out:
# -2

# %%
5*7
# Out:
# 35

# %%
5/7
# Out:
# 0.7142857142857143

# %%
55//7
# Out:
# 7

# %%
55%7
# Out:
# 6

# %%
3**8
# Out:
# 6561

# %%
5**2*(8+6)/14
# Out:
# 25.0

# %%
7+25/5+4
# Out:
# 16.0

# %%
d
# Out:
# 8

# %%
d+=1

# %%
d
# Out:
# 9

# %%
d-=2

# %%
d
# Out:
# 7

# %%
d*=4

# %%
d
# Out:
# 28

# %%
d/=3

# %%
d
# Out:
# 9.333333333333334

# %%
d = d*3 #same ass d*=3

# %%
d
# Out:
# 28.0

# %%
radius<square10
# Out:
# False

# %%
print(radius,square10)
# Out:
# 10 5

# %%
radius>square10
# Out:
# True

# %%
radius==square10
# Out:
# False

# %%
radius<radius
# Out:
# False

# %%
radius<=radius
# Out:
# True

# %% [markdown]
# ## Python Modules

# %%
help('modules')
# Out:
# Please wait a moment while I gather a list of all available modules...
# /srv/conda/envs/notebook/lib/python3.7/site-packages/IPython/kernel/__init__.py:13: ShimWarning: The `IPython.kernel` package has been deprecated since IPython 4.0.You should import from ipykernel or jupyter_client instead.
#   "You should import from ipykernel or jupyter_client instead.", ShimWarning)
# /srv/conda/envs/notebook/lib/python3.7/site-packages/_distutils_hack/__init__.py:33: UserWarning: Setuptools is replacing distutils.
#   warnings.warn("Setuptools is replacing distutils.")
# IPython             asyncore            ipython_genutils    re
# OpenSSL             atexit              ipywidgets          readline
# PIL                 attr                itertools           reprlib
# __future__          attrs               jedi                requests
# _abc                audioop             jinja2              resource
# _argon2_cffi_bindings autoreload          json                rlcompleter
# ...

# %%
import math

# %%
math.fabs(-17.8)
# Out:
# 17.8

# %%
import matplotlib.pyplot as plt

# %%
a=(0,1,2,3,4,5,6,7)
b=(1,2,3,4,9,16,25,36,49)
plt.plot(a,b,'^',c=#)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipykernel_87/723027718.py in <module>
#       1 a=(0,1,2,3,4,5,6,7)
#       2 b=(1,2,3,4,9,16,25,36,49)
# ----> 3 plt.plot(a,b,'o')
#
# /srv/conda/envs/notebook/lib/python3.7/site-packages/matplotlib/pyplot.py in plot(scalex, scaley, data, *args, **kwargs)
#    2767     return gca().plot(
#    2768         *args, scalex=scalex, scaley=scaley,
# -> 2769         **({"data": data} if data is not None else {}), **kwargs)
#    2770
#    2771
#
# /srv/conda/envs/notebook/lib/python3.7/site-packages/matplotlib/axes/_axes.py in plot(self, scalex, scaley, data, *args, **kwargs)
#    1633         """
#    1634         kwargs = cbook.normalize_kwargs(kwargs, mlines.Line2D)
# -> 1635         lines = [*self._get_lines(*args, data=data, **kwargs)]
#    1636         for line in lines:
#    1637             self.add_line(line)
#
# ...

# %%
math.cos(math.pi)
# Out:
# -1.0

# %%
cos(pi)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_87/931161562.py in <module>
# ----> 1 cos(pi)
#
# NameError: name 'cos' is not defined

# %%
def cos(angle):
    return math.cos(angle)
pi=math.pi

# %%
cos(pi/4)
# Out:
# 0.7071067811865476

# %%
cos(0)
# Out:
# 1.0

# %%
len(a)
# Out:
# 8

# %%
(0)*len(a)
# Out:
# 0

# %%
def spiralX(thelist):
            x=(0)*(thelist)
            for i in range(len(thelist)):
                x(i) = math.cos(thelist(i)*thelist(i)**0.5
                         
                            def spiralY(thelist):
                            y = [0]*len(thelist)
                            for i in range(len(thelist)):
                            y(i) = math.sin(thelist(i]+1)*(thelist(i)**0.5
                                                           return y
# Out:
#   File "/tmp/ipykernel_87/3824107880.py", line 6
#     def spiralY(thelist):
#       ^
# SyntaxError: invalid syntax
